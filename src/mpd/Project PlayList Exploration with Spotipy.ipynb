# %% [markdown]
# **Exploring Spotify PlayLists for Track Identification**

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

cid ="07ca03cba8534f969d080936d5833062"
 
secret = "fbfcbbd68f884d5e887d7b502f97a036"

client_credentials_manager = SpotifyClientCredentials(client_id=cid, client_secret=secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
import numpy as np
import scipy.stats
import scipy.special

import matplotlib
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
from matplotlib import cm

from bs4 import BeautifulSoup

import pandas as pd
import seaborn as sns

# %matplotlib inline

# %%
def show_tracks(results):
    for i, item in enumerate(tracks['items']):
        track = item['track']
        print("   %d %32.32s %s" % (i, track['artists'][0]['name'], track['name']))

# %%
username="wu8kq8i7s861vw8f5o071slsk"
playlists = sp.user_playlists("wu8kq8i7s861vw8f5o071slsk")
for playlist in playlists['items']:
        if playlist['owner']['id'] == username:
            print()
            print(playlist['name'])
            print('  total tracks', playlist['tracks']['total'])
            results = sp.user_playlist(username, playlist['id'], fields="tracks,next")
            
            tracks = results['tracks']
            show_tracks(tracks)
            while tracks['next']:
                tracks = sp.next(tracks)
                show_tracks(tracks)
# Out:
# Driving
#   total tracks 7
#    0                     Travis Scott SICKO MODE
#    1                         Jay Rock WIN
#    2                        Sheck Wes Live SheckWes Die SheckWes
#    3                      Nicki Minaj Chun-Li
#    4                         Skrillex Purple Lamborghini (with Rick Ross)
#    5                 Childish Gambino This Is America
#    6                          Pusha T If You Know You Know
#
# Studying
#   total tracks 6
#    0          Wolfgang Amadeus Mozart Requiem, K. 626: Lacrimosa
#    1          Wolfgang Amadeus Mozart Requiem, K. 626: Lacrimosa
#    2          Wolfgang Amadeus Mozart Requiem, K. 626: Lacrimosa
#    3                   Mozart La Para Mujeres (Mozart La Para, Justin Quiles, Farruko, Jowell & Randy) - Remix
#    4          Wolfgang Amadeus Mozart Piano Concerto No. 21 in C Major, K. 467 "Elvira Madigan": II. Andante
#    5          Wolfgang Amadeus Mozart Piano Concerto No. 21 in C Major, K. 467 "Elvira Madigan": II. Andante

# %%
tracks.get('items')
# Out:
# [{'added_at': '2018-10-31T15:02:19Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/wu8kq8i7s861vw8f5o071slsk'},
#    'href': 'https://api.spotify.com/v1/users/wu8kq8i7s861vw8f5o071slsk',
#    'id': 'wu8kq8i7s861vw8f5o071slsk',
#    'type': 'user',
#    'uri': 'spotify:user:wu8kq8i7s861vw8f5o071slsk'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4NJhFmfw43RLBLjQvxDuRS'},
#       'href': 'https://api.spotify.com/v1/artists/4NJhFmfw43RLBLjQvxDuRS',
#       'id': '4NJhFmfw43RLBLjQvxDuRS',
#       'name': 'Wolfgang Amadeus Mozart',
#       'type': 'artist',
#       'uri': 'spotify:artist:4NJhFmfw43RLBLjQvxDuRS'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/60adCptqwRkANTtVja0bvf'},
#       'href': 'https://api.spotify.com/v1/artists/60adCptqwRkANTtVja0bvf',
#       'id': '60adCptqwRkANTtVja0bvf',
#       'name': 'Academy of Ancient Music',
#       'type': 'artist',
#       'uri': 'spotify:artist:60adCptqwRkANTtVja0bvf'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/0ugRf6ECGBFRCHlv9iG1No'},
#       'href': 'https://api.spotify.com/v1/artists/0ugRf6ECGBFRCHlv9iG1No',
#       'id': '0ugRf6ECGBFRCHlv9iG1No',
#       'name': 'Stephen Cleobury',
#       'type': 'artist',
#       'uri': 'spotify:artist:0ugRf6ECGBFRCHlv9iG1No'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/0f3PsS9IQ6whvNMFFKnpjl'},
#       'href': 'https://api.spotify.com/v1/artists/0f3PsS9IQ6whvNMFFKnpjl',
#       'id': '0f3PsS9IQ6whvNMFFKnpjl',
#       'name': "Choir of King's College, Cambridge",
#       'type': 'artist',
#       'uri': 'spotify:artist:0f3PsS9IQ6whvNMFFKnpjl'}],
#     'available_markets': ['AD',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'EC',
#      'EE',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IS',
#      'IT',
#      'JP',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'RO',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2wNvwhS6pLo6jFydj10KCt'},
#     'href': 'https://api.spotify.com/v1/albums/2wNvwhS6pLo6jFydj10KCt',
#     'id': '2wNvwhS6pLo6jFydj10KCt',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/290e91aa4638abc59bb787a23588c2c8fc008d24',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/4a4e9ccec9b746b2daaea88d3ca68173518196fc',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/2476e1d84ad49ed2b8614422eb66f8ed8c9445e3',
#       'width': 64}],
#     'name': 'Mozart: Requiem Realisations',
#     'release_date': '2013-04-08',
#     'release_date_precision': 'day',
#     'total_tracks': 23,
#     'type': 'album',
#     'uri': 'spotify:album:2wNvwhS6pLo6jFydj10KCt'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4NJhFmfw43RLBLjQvxDuRS'},
#      'href': 'https://api.spotify.com/v1/artists/4NJhFmfw43RLBLjQvxDuRS',
#      'id': '4NJhFmfw43RLBLjQvxDuRS',
#      'name': 'Wolfgang Amadeus Mozart',
#      'type': 'artist',
#      'uri': 'spotify:artist:4NJhFmfw43RLBLjQvxDuRS'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/60adCptqwRkANTtVja0bvf'},
#      'href': 'https://api.spotify.com/v1/artists/60adCptqwRkANTtVja0bvf',
#      'id': '60adCptqwRkANTtVja0bvf',
#      'name': 'Academy of Ancient Music',
#      'type': 'artist',
#      'uri': 'spotify:artist:60adCptqwRkANTtVja0bvf'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/0ugRf6ECGBFRCHlv9iG1No'},
#      'href': 'https://api.spotify.com/v1/artists/0ugRf6ECGBFRCHlv9iG1No',
#      'id': '0ugRf6ECGBFRCHlv9iG1No',
#      'name': 'Stephen Cleobury',
#      'type': 'artist',
#      'uri': 'spotify:artist:0ugRf6ECGBFRCHlv9iG1No'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/0f3PsS9IQ6whvNMFFKnpjl'},
#      'href': 'https://api.spotify.com/v1/artists/0f3PsS9IQ6whvNMFFKnpjl',
#      'id': '0f3PsS9IQ6whvNMFFKnpjl',
#      'name': "Choir of King's College, Cambridge",
#      'type': 'artist',
#      'uri': 'spotify:artist:0f3PsS9IQ6whvNMFFKnpjl'}],
#    'available_markets': ['AD',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'EC',
#     'EE',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IS',
#     'IT',
#     'JP',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'PY',
#     'RO',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 169666,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBMY51300208'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3oHSL6pt9LpNrQZuQGu9wL'},
#    'href': 'https://api.spotify.com/v1/tracks/3oHSL6pt9LpNrQZuQGu9wL',
#    'id': '3oHSL6pt9LpNrQZuQGu9wL',
#    'is_local': False,
#    'name': 'Requiem, K. 626: Lacrimosa',
#    'popularity': 63,
#    'preview_url': 'https://p.scdn.co/mp3-preview/1ca401d878d3a14f1ab17ba850345633fbcd65e3?cid=07ca03cba8534f969d080936d5833062',
#    'track': True,
#    'track_number': 8,
#    'type': 'track',
#    'uri': 'spotify:track:3oHSL6pt9LpNrQZuQGu9wL'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2018-10-31T15:02:23Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/wu8kq8i7s861vw8f5o071slsk'},
#    'href': 'https://api.spotify.com/v1/users/wu8kq8i7s861vw8f5o071slsk',
#    'id': 'wu8kq8i7s861vw8f5o071slsk',
#    'type': 'user',
#    'uri': 'spotify:user:wu8kq8i7s861vw8f5o071slsk'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4NJhFmfw43RLBLjQvxDuRS'},
#       'href': 'https://api.spotify.com/v1/artists/4NJhFmfw43RLBLjQvxDuRS',
#       'id': '4NJhFmfw43RLBLjQvxDuRS',
#       'name': 'Wolfgang Amadeus Mozart',
#       'type': 'artist',
#       'uri': 'spotify:artist:4NJhFmfw43RLBLjQvxDuRS'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/60adCptqwRkANTtVja0bvf'},
#       'href': 'https://api.spotify.com/v1/artists/60adCptqwRkANTtVja0bvf',
#       'id': '60adCptqwRkANTtVja0bvf',
#       'name': 'Academy of Ancient Music',
#       'type': 'artist',
#       'uri': 'spotify:artist:60adCptqwRkANTtVja0bvf'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/0ugRf6ECGBFRCHlv9iG1No'},
#       'href': 'https://api.spotify.com/v1/artists/0ugRf6ECGBFRCHlv9iG1No',
#       'id': '0ugRf6ECGBFRCHlv9iG1No',
#       'name': 'Stephen Cleobury',
#       'type': 'artist',
#       'uri': 'spotify:artist:0ugRf6ECGBFRCHlv9iG1No'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/0f3PsS9IQ6whvNMFFKnpjl'},
#       'href': 'https://api.spotify.com/v1/artists/0f3PsS9IQ6whvNMFFKnpjl',
#       'id': '0f3PsS9IQ6whvNMFFKnpjl',
#       'name': "Choir of King's College, Cambridge",
#       'type': 'artist',
#       'uri': 'spotify:artist:0f3PsS9IQ6whvNMFFKnpjl'}],
#     'available_markets': ['AD',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'EC',
#      'EE',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IS',
#      'IT',
#      'JP',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'RO',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2wNvwhS6pLo6jFydj10KCt'},
#     'href': 'https://api.spotify.com/v1/albums/2wNvwhS6pLo6jFydj10KCt',
#     'id': '2wNvwhS6pLo6jFydj10KCt',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/290e91aa4638abc59bb787a23588c2c8fc008d24',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/4a4e9ccec9b746b2daaea88d3ca68173518196fc',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/2476e1d84ad49ed2b8614422eb66f8ed8c9445e3',
#       'width': 64}],
#     'name': 'Mozart: Requiem Realisations',
#     'release_date': '2013-04-08',
#     'release_date_precision': 'day',
#     'total_tracks': 23,
#     'type': 'album',
#     'uri': 'spotify:album:2wNvwhS6pLo6jFydj10KCt'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4NJhFmfw43RLBLjQvxDuRS'},
#      'href': 'https://api.spotify.com/v1/artists/4NJhFmfw43RLBLjQvxDuRS',
#      'id': '4NJhFmfw43RLBLjQvxDuRS',
#      'name': 'Wolfgang Amadeus Mozart',
#      'type': 'artist',
#      'uri': 'spotify:artist:4NJhFmfw43RLBLjQvxDuRS'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/60adCptqwRkANTtVja0bvf'},
#      'href': 'https://api.spotify.com/v1/artists/60adCptqwRkANTtVja0bvf',
#      'id': '60adCptqwRkANTtVja0bvf',
#      'name': 'Academy of Ancient Music',
#      'type': 'artist',
#      'uri': 'spotify:artist:60adCptqwRkANTtVja0bvf'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/0ugRf6ECGBFRCHlv9iG1No'},
#      'href': 'https://api.spotify.com/v1/artists/0ugRf6ECGBFRCHlv9iG1No',
#      'id': '0ugRf6ECGBFRCHlv9iG1No',
#      'name': 'Stephen Cleobury',
#      'type': 'artist',
#      'uri': 'spotify:artist:0ugRf6ECGBFRCHlv9iG1No'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/0f3PsS9IQ6whvNMFFKnpjl'},
#      'href': 'https://api.spotify.com/v1/artists/0f3PsS9IQ6whvNMFFKnpjl',
#      'id': '0f3PsS9IQ6whvNMFFKnpjl',
#      'name': "Choir of King's College, Cambridge",
#      'type': 'artist',
#      'uri': 'spotify:artist:0f3PsS9IQ6whvNMFFKnpjl'}],
#    'available_markets': ['AD',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'EC',
#     'EE',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IS',
#     'IT',
#     'JP',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'PY',
#     'RO',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 169666,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBMY51300208'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3oHSL6pt9LpNrQZuQGu9wL'},
#    'href': 'https://api.spotify.com/v1/tracks/3oHSL6pt9LpNrQZuQGu9wL',
#    'id': '3oHSL6pt9LpNrQZuQGu9wL',
#    'is_local': False,
#    'name': 'Requiem, K. 626: Lacrimosa',
#    'popularity': 63,
#    'preview_url': 'https://p.scdn.co/mp3-preview/1ca401d878d3a14f1ab17ba850345633fbcd65e3?cid=07ca03cba8534f969d080936d5833062',
#    'track': True,
#    'track_number': 8,
#    'type': 'track',
#    'uri': 'spotify:track:3oHSL6pt9LpNrQZuQGu9wL'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2018-10-31T15:02:30Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/wu8kq8i7s861vw8f5o071slsk'},
#    'href': 'https://api.spotify.com/v1/users/wu8kq8i7s861vw8f5o071slsk',
#    'id': 'wu8kq8i7s861vw8f5o071slsk',
#    'type': 'user',
#    'uri': 'spotify:user:wu8kq8i7s861vw8f5o071slsk'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4NJhFmfw43RLBLjQvxDuRS'},
#       'href': 'https://api.spotify.com/v1/artists/4NJhFmfw43RLBLjQvxDuRS',
#       'id': '4NJhFmfw43RLBLjQvxDuRS',
#       'name': 'Wolfgang Amadeus Mozart',
#       'type': 'artist',
#       'uri': 'spotify:artist:4NJhFmfw43RLBLjQvxDuRS'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/60adCptqwRkANTtVja0bvf'},
#       'href': 'https://api.spotify.com/v1/artists/60adCptqwRkANTtVja0bvf',
#       'id': '60adCptqwRkANTtVja0bvf',
#       'name': 'Academy of Ancient Music',
#       'type': 'artist',
#       'uri': 'spotify:artist:60adCptqwRkANTtVja0bvf'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/0ugRf6ECGBFRCHlv9iG1No'},
#       'href': 'https://api.spotify.com/v1/artists/0ugRf6ECGBFRCHlv9iG1No',
#       'id': '0ugRf6ECGBFRCHlv9iG1No',
#       'name': 'Stephen Cleobury',
#       'type': 'artist',
#       'uri': 'spotify:artist:0ugRf6ECGBFRCHlv9iG1No'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/0f3PsS9IQ6whvNMFFKnpjl'},
#       'href': 'https://api.spotify.com/v1/artists/0f3PsS9IQ6whvNMFFKnpjl',
#       'id': '0f3PsS9IQ6whvNMFFKnpjl',
#       'name': "Choir of King's College, Cambridge",
#       'type': 'artist',
#       'uri': 'spotify:artist:0f3PsS9IQ6whvNMFFKnpjl'}],
#     'available_markets': ['AD',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'EC',
#      'EE',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IS',
#      'IT',
#      'JP',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'RO',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2wNvwhS6pLo6jFydj10KCt'},
#     'href': 'https://api.spotify.com/v1/albums/2wNvwhS6pLo6jFydj10KCt',
#     'id': '2wNvwhS6pLo6jFydj10KCt',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/290e91aa4638abc59bb787a23588c2c8fc008d24',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/4a4e9ccec9b746b2daaea88d3ca68173518196fc',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/2476e1d84ad49ed2b8614422eb66f8ed8c9445e3',
#       'width': 64}],
#     'name': 'Mozart: Requiem Realisations',
#     'release_date': '2013-04-08',
#     'release_date_precision': 'day',
#     'total_tracks': 23,
#     'type': 'album',
#     'uri': 'spotify:album:2wNvwhS6pLo6jFydj10KCt'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4NJhFmfw43RLBLjQvxDuRS'},
#      'href': 'https://api.spotify.com/v1/artists/4NJhFmfw43RLBLjQvxDuRS',
#      'id': '4NJhFmfw43RLBLjQvxDuRS',
#      'name': 'Wolfgang Amadeus Mozart',
#      'type': 'artist',
#      'uri': 'spotify:artist:4NJhFmfw43RLBLjQvxDuRS'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/60adCptqwRkANTtVja0bvf'},
#      'href': 'https://api.spotify.com/v1/artists/60adCptqwRkANTtVja0bvf',
#      'id': '60adCptqwRkANTtVja0bvf',
#      'name': 'Academy of Ancient Music',
#      'type': 'artist',
#      'uri': 'spotify:artist:60adCptqwRkANTtVja0bvf'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/0ugRf6ECGBFRCHlv9iG1No'},
#      'href': 'https://api.spotify.com/v1/artists/0ugRf6ECGBFRCHlv9iG1No',
#      'id': '0ugRf6ECGBFRCHlv9iG1No',
#      'name': 'Stephen Cleobury',
#      'type': 'artist',
#      'uri': 'spotify:artist:0ugRf6ECGBFRCHlv9iG1No'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/0f3PsS9IQ6whvNMFFKnpjl'},
#      'href': 'https://api.spotify.com/v1/artists/0f3PsS9IQ6whvNMFFKnpjl',
#      'id': '0f3PsS9IQ6whvNMFFKnpjl',
#      'name': "Choir of King's College, Cambridge",
#      'type': 'artist',
#      'uri': 'spotify:artist:0f3PsS9IQ6whvNMFFKnpjl'}],
#    'available_markets': ['AD',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'EC',
#     'EE',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IS',
#     'IT',
#     'JP',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'PY',
#     'RO',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 169666,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBMY51300208'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3oHSL6pt9LpNrQZuQGu9wL'},
#    'href': 'https://api.spotify.com/v1/tracks/3oHSL6pt9LpNrQZuQGu9wL',
#    'id': '3oHSL6pt9LpNrQZuQGu9wL',
#    'is_local': False,
#    'name': 'Requiem, K. 626: Lacrimosa',
#    'popularity': 63,
#    'preview_url': 'https://p.scdn.co/mp3-preview/1ca401d878d3a14f1ab17ba850345633fbcd65e3?cid=07ca03cba8534f969d080936d5833062',
#    'track': True,
#    'track_number': 8,
#    'type': 'track',
#    'uri': 'spotify:track:3oHSL6pt9LpNrQZuQGu9wL'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2018-10-31T15:02:36Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/wu8kq8i7s861vw8f5o071slsk'},
#    'href': 'https://api.spotify.com/v1/users/wu8kq8i7s861vw8f5o071slsk',
#    'id': 'wu8kq8i7s861vw8f5o071slsk',
#    'type': 'user',
#    'uri': 'spotify:user:wu8kq8i7s861vw8f5o071slsk'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0odliLZMTk45CEVzF3Zocl'},
#       'href': 'https://api.spotify.com/v1/artists/0odliLZMTk45CEVzF3Zocl',
#       'id': '0odliLZMTk45CEVzF3Zocl',
#       'name': 'Mozart La Para',
#       'type': 'artist',
#       'uri': 'spotify:artist:0odliLZMTk45CEVzF3Zocl'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/14zUHaJZo1mnYtn6IBRaRP'},
#       'href': 'https://api.spotify.com/v1/artists/14zUHaJZo1mnYtn6IBRaRP',
#       'id': '14zUHaJZo1mnYtn6IBRaRP',
#       'name': 'Justin Quiles',
#       'type': 'artist',
#       'uri': 'spotify:artist:14zUHaJZo1mnYtn6IBRaRP'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/329e4yvIujISKGKz1BZZbO'},
#       'href': 'https://api.spotify.com/v1/artists/329e4yvIujISKGKz1BZZbO',
#       'id': '329e4yvIujISKGKz1BZZbO',
#       'name': 'Farruko',
#       'type': 'artist',
#       'uri': 'spotify:artist:329e4yvIujISKGKz1BZZbO'}],
#     'available_markets': ['AD',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'EC',
#      'EE',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IS',
#      'IT',
#      'JP',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'RO',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6nGSrip9wzmYQLsSSkNjSP'},
#     'href': 'https://api.spotify.com/v1/albums/6nGSrip9wzmYQLsSSkNjSP',
#     'id': '6nGSrip9wzmYQLsSSkNjSP',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/2f2d16119ccd87b9b4742d47ae2339673e229c65',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/8cddeafb23e1f2f0b9fb35aad6935ae2482c6738',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/662850c6b5271228bee74810dca28975d7682cab',
#       'width': 64}],
#     'name': 'Mujeres (Mozart La Para, Justin Quiles, Farruko, Jowell & Randy) [Remix]',
#     'release_date': '2018-10-19',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:6nGSrip9wzmYQLsSSkNjSP'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0odliLZMTk45CEVzF3Zocl'},
#      'href': 'https://api.spotify.com/v1/artists/0odliLZMTk45CEVzF3Zocl',
#      'id': '0odliLZMTk45CEVzF3Zocl',
#      'name': 'Mozart La Para',
#      'type': 'artist',
#      'uri': 'spotify:artist:0odliLZMTk45CEVzF3Zocl'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/14zUHaJZo1mnYtn6IBRaRP'},
#      'href': 'https://api.spotify.com/v1/artists/14zUHaJZo1mnYtn6IBRaRP',
#      'id': '14zUHaJZo1mnYtn6IBRaRP',
#      'name': 'Justin Quiles',
#      'type': 'artist',
#      'uri': 'spotify:artist:14zUHaJZo1mnYtn6IBRaRP'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/329e4yvIujISKGKz1BZZbO'},
#      'href': 'https://api.spotify.com/v1/artists/329e4yvIujISKGKz1BZZbO',
#      'id': '329e4yvIujISKGKz1BZZbO',
#      'name': 'Farruko',
#      'type': 'artist',
#      'uri': 'spotify:artist:329e4yvIujISKGKz1BZZbO'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/4IMAo2UQchVFyPH24PAjUs'},
#      'href': 'https://api.spotify.com/v1/artists/4IMAo2UQchVFyPH24PAjUs',
#      'id': '4IMAo2UQchVFyPH24PAjUs',
#      'name': 'Jowell & Randy',
#      'type': 'artist',
#      'uri': 'spotify:artist:4IMAo2UQchVFyPH24PAjUs'}],
#    'available_markets': ['AD',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'EC',
#     'EE',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IS',
#     'IT',
#     'JP',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'PY',
#     'RO',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 236200,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'QMJMT1801888'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/1AKP5JySgNsr2Y04z1yGHJ'},
#    'href': 'https://api.spotify.com/v1/tracks/1AKP5JySgNsr2Y04z1yGHJ',
#    'id': '1AKP5JySgNsr2Y04z1yGHJ',
#    'is_local': False,
#    'name': 'Mujeres (Mozart La Para, Justin Quiles, Farruko, Jowell & Randy) - Remix',
#    'popularity': 68,
#    'preview_url': None,
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:1AKP5JySgNsr2Y04z1yGHJ'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2018-10-31T15:03:33Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/wu8kq8i7s861vw8f5o071slsk'},
#    'href': 'https://api.spotify.com/v1/users/wu8kq8i7s861vw8f5o071slsk',
#    'id': 'wu8kq8i7s861vw8f5o071slsk',
#    'type': 'user',
#    'uri': 'spotify:user:wu8kq8i7s861vw8f5o071slsk'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4NJhFmfw43RLBLjQvxDuRS'},
#       'href': 'https://api.spotify.com/v1/artists/4NJhFmfw43RLBLjQvxDuRS',
#       'id': '4NJhFmfw43RLBLjQvxDuRS',
#       'name': 'Wolfgang Amadeus Mozart',
#       'type': 'artist',
#       'uri': 'spotify:artist:4NJhFmfw43RLBLjQvxDuRS'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/3pxt6077A2xXBAgMrgHRPg'},
#       'href': 'https://api.spotify.com/v1/artists/3pxt6077A2xXBAgMrgHRPg',
#       'id': '3pxt6077A2xXBAgMrgHRPg',
#       'name': 'Howard Shelley',
#       'type': 'artist',
#       'uri': 'spotify:artist:3pxt6077A2xXBAgMrgHRPg'}],
#     'available_markets': ['AD',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'EC',
#      'EE',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IS',
#      'IT',
#      'JP',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'RO',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/1w23oh2TlwHKxaCYJU8oGO'},
#     'href': 'https://api.spotify.com/v1/albums/1w23oh2TlwHKxaCYJU8oGO',
#     'id': '1w23oh2TlwHKxaCYJU8oGO',
#     'images': [{'height': 627,
#       'url': 'https://i.scdn.co/image/d19c4b6ee4ab3874ace420da8f034d5ec3b71d7a',
#       'width': 640},
#      {'height': 294,
#       'url': 'https://i.scdn.co/image/d3f7105c9a0b62ced2335e557117ac2ea8729cbe',
#       'width': 300},
#      {'height': 63,
#       'url': 'https://i.scdn.co/image/426cbdf769360d9af8eb8ea241549b3b366db42c',
#       'width': 64}],
#     'name': 'Mozart: Piano Concertos, Vol. 6',
#     'release_date': '1995-11-01',
#     'release_date_precision': 'day',
#     'total_tracks': 6,
#     'type': 'album',
#     'uri': 'spotify:album:1w23oh2TlwHKxaCYJU8oGO'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4NJhFmfw43RLBLjQvxDuRS'},
#      'href': 'https://api.spotify.com/v1/artists/4NJhFmfw43RLBLjQvxDuRS',
#      'id': '4NJhFmfw43RLBLjQvxDuRS',
#      'name': 'Wolfgang Amadeus Mozart',
#      'type': 'artist',
#      'uri': 'spotify:artist:4NJhFmfw43RLBLjQvxDuRS'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/3pxt6077A2xXBAgMrgHRPg'},
#      'href': 'https://api.spotify.com/v1/artists/3pxt6077A2xXBAgMrgHRPg',
#      'id': '3pxt6077A2xXBAgMrgHRPg',
#      'name': 'Howard Shelley',
#      'type': 'artist',
#      'uri': 'spotify:artist:3pxt6077A2xXBAgMrgHRPg'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/1sylrdKARMDYTJbs8IPWGy'},
#      'href': 'https://api.spotify.com/v1/artists/1sylrdKARMDYTJbs8IPWGy',
#      'id': '1sylrdKARMDYTJbs8IPWGy',
#      'name': 'London Mozart Players',
#      'type': 'artist',
#      'uri': 'spotify:artist:1sylrdKARMDYTJbs8IPWGy'}],
#    'available_markets': ['AD',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'EC',
#     'EE',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IS',
#     'IT',
#     'JP',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'PY',
#     'RO',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 433800,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBLWD9511002'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2YarjDYjBJuH63dUIh9OWv'},
#    'href': 'https://api.spotify.com/v1/tracks/2YarjDYjBJuH63dUIh9OWv',
#    'id': '2YarjDYjBJuH63dUIh9OWv',
#    'is_local': False,
#    'name': 'Piano Concerto No. 21 in C Major, K. 467 "Elvira Madigan": II. Andante',
#    'popularity': 67,
#    'preview_url': 'https://p.scdn.co/mp3-preview/e2b78e7d24fa4d5a278154f34e8d753cc0e7c79a?cid=07ca03cba8534f969d080936d5833062',
#    'track': True,
#    'track_number': 2,
#    'type': 'track',
#    'uri': 'spotify:track:2YarjDYjBJuH63dUIh9OWv'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2018-10-31T15:03:33Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/wu8kq8i7s861vw8f5o071slsk'},
#    'href': 'https://api.spotify.com/v1/users/wu8kq8i7s861vw8f5o071slsk',
#    'id': 'wu8kq8i7s861vw8f5o071slsk',
#    'type': 'user',
#    'uri': 'spotify:user:wu8kq8i7s861vw8f5o071slsk'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4NJhFmfw43RLBLjQvxDuRS'},
#       'href': 'https://api.spotify.com/v1/artists/4NJhFmfw43RLBLjQvxDuRS',
#       'id': '4NJhFmfw43RLBLjQvxDuRS',
#       'name': 'Wolfgang Amadeus Mozart',
#       'type': 'artist',
#       'uri': 'spotify:artist:4NJhFmfw43RLBLjQvxDuRS'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/3pxt6077A2xXBAgMrgHRPg'},
#       'href': 'https://api.spotify.com/v1/artists/3pxt6077A2xXBAgMrgHRPg',
#       'id': '3pxt6077A2xXBAgMrgHRPg',
#       'name': 'Howard Shelley',
#       'type': 'artist',
#       'uri': 'spotify:artist:3pxt6077A2xXBAgMrgHRPg'}],
#     'available_markets': ['AD',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'EC',
#      'EE',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IS',
#      'IT',
#      'JP',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'RO',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/1w23oh2TlwHKxaCYJU8oGO'},
#     'href': 'https://api.spotify.com/v1/albums/1w23oh2TlwHKxaCYJU8oGO',
#     'id': '1w23oh2TlwHKxaCYJU8oGO',
#     'images': [{'height': 627,
#       'url': 'https://i.scdn.co/image/d19c4b6ee4ab3874ace420da8f034d5ec3b71d7a',
#       'width': 640},
#      {'height': 294,
#       'url': 'https://i.scdn.co/image/d3f7105c9a0b62ced2335e557117ac2ea8729cbe',
#       'width': 300},
#      {'height': 63,
#       'url': 'https://i.scdn.co/image/426cbdf769360d9af8eb8ea241549b3b366db42c',
#       'width': 64}],
#     'name': 'Mozart: Piano Concertos, Vol. 6',
#     'release_date': '1995-11-01',
#     'release_date_precision': 'day',
#     'total_tracks': 6,
#     'type': 'album',
#     'uri': 'spotify:album:1w23oh2TlwHKxaCYJU8oGO'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4NJhFmfw43RLBLjQvxDuRS'},
#      'href': 'https://api.spotify.com/v1/artists/4NJhFmfw43RLBLjQvxDuRS',
#      'id': '4NJhFmfw43RLBLjQvxDuRS',
#      'name': 'Wolfgang Amadeus Mozart',
#      'type': 'artist',
#      'uri': 'spotify:artist:4NJhFmfw43RLBLjQvxDuRS'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/3pxt6077A2xXBAgMrgHRPg'},
#      'href': 'https://api.spotify.com/v1/artists/3pxt6077A2xXBAgMrgHRPg',
#      'id': '3pxt6077A2xXBAgMrgHRPg',
#      'name': 'Howard Shelley',
#      'type': 'artist',
#      'uri': 'spotify:artist:3pxt6077A2xXBAgMrgHRPg'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/1sylrdKARMDYTJbs8IPWGy'},
#      'href': 'https://api.spotify.com/v1/artists/1sylrdKARMDYTJbs8IPWGy',
#      'id': '1sylrdKARMDYTJbs8IPWGy',
#      'name': 'London Mozart Players',
#      'type': 'artist',
#      'uri': 'spotify:artist:1sylrdKARMDYTJbs8IPWGy'}],
#    'available_markets': ['AD',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'EC',
#     'EE',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IS',
#     'IT',
#     'JP',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'PY',
#     'RO',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 433800,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBLWD9511002'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2YarjDYjBJuH63dUIh9OWv'},
#    'href': 'https://api.spotify.com/v1/tracks/2YarjDYjBJuH63dUIh9OWv',
#    'id': '2YarjDYjBJuH63dUIh9OWv',
#    'is_local': False,
#    'name': 'Piano Concerto No. 21 in C Major, K. 467 "Elvira Madigan": II. Andante',
#    'popularity': 67,
#    'preview_url': 'https://p.scdn.co/mp3-preview/e2b78e7d24fa4d5a278154f34e8d753cc0e7c79a?cid=07ca03cba8534f969d080936d5833062',
#    'track': True,
#    'track_number': 2,
#    'type': 'track',
#    'uri': 'spotify:track:2YarjDYjBJuH63dUIh9OWv'},
#   'video_thumbnail': {'url': None}}]
